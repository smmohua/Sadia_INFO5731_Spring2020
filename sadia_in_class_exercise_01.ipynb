# %% [markdown]
# <a href="https://colab.research.google.com/github/smmohua/Sadia_INFO5731_Spring2020/blob/main/sadia_in_class_exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (1) Write a Python program to calculate the length of a string. (4 points)

# %%
my_str='Spring_2022'
str_len=len(my_str)
print(str_len)
# Out:
# 11
